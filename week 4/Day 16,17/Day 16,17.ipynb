# %%
# %matplotlib inline
import pandas as pd

# %%
# from IPython.core.display import HTML
# css = open('style-table.css').read() + open('style-notebook.css').read()
# HTML('<style>{}</style>'.format(css))

# %%
titles = pd.read_csv('Dataset/titles.csv')
titles.head()
# Out:
#                   title  year
# 0    Tasveer Mere Sanam  1996
# 1              Only You  1994
# 2  El pueblo del terror  1970
# 3               Machine  2007
# 4                  MARy  2008

# %%
cast = pd.read_csv('Dataset/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
cast.shape
# Out:
# (3786176, 6)

# %%
titles.shape
# Out:
# (244914, 2)

# %%
release_dates = pd.read_csv('Dataset/release_dates.csv')
release_dates.head()
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                   #BKKY  2016     Cambodia  2017-10-12
# 2                 #Beings  2015      Romania  2015-01-29
# 3               #Captured  2017          USA  2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21

# %%
release_dates.shape
# Out:
# (479488, 4)

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
sum = titles['title'].count()

# %%
print("Number of movies that are listed in the titles dataframe is:",sum)
# Out:
# Number of movies that are listed in the titles dataframe is: 244914

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
print("The earliest two films listed in the titles dataframe are:")

sorted1 = titles.sort_values('year').reset_index(drop=True).head(2)
list1 = list(sorted1['title'])
print(list1)
# Out:
# The earliest two films listed in the titles dataframe are:
# ['Miss Jerry', 'The Startled Lover']

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
print("The Number of movie with \"Hamlet\" as the Title are:")
print(len(titles[titles.title == 'Hamlet']))
# Out:
# The Number of movie with "Hamlet" as the Title are:
# 20

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
print("The Number of movie with \"North by Northwest\" as the Title are:")
print(len(titles[titles.title == 'North by Northwest']))
# Out:
# The Number of movie with "North by Northwest" as the Title are:
# 1

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
print("The First movie with \"Hamlet\" as the Title is:")
fst = int(titles[titles.title == 'Hamlet'].sort_values('year').reset_index(drop=True).year.head(1))
print(fst)
# Out:
# The First movie with "Hamlet" as the Title is:
# 1910

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
print("All of the \"Treasure Island\" movies from earliest to most recent are:")
print(titles[titles.title == 'Treasure Island'].sort_values('year').reset_index(drop=True).head())
# Out:
# All of the "Treasure Island" movies from earliest to most recent are:
#              title  year
# 0  Treasure Island  1918
# 1  Treasure Island  1920
# 2  Treasure Island  1934
# 3  Treasure Island  1950
# 4  Treasure Island  1972

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
print("Number of movies that were made in the year 1950 is:")
print(len(titles[titles.year == 1950]))
# Out:
# Number of movies that were made in the year 1950 is:
# 1113

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
print("Number of movies that were made in the year 1960 is:")
print(len(titles[titles.year == 1960]))
# Out:
# Number of movies that were made in the year 1960 is:
# 1549

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
print("The number of movies that were made from 1950 through 1959 is:")
sum = 0
for i in range(1950,1960):
    sum = sum + len(titles[titles.year == i])
print(sum)
# Out:
# The number of movies that were made from 1950 through 1959 is:
# 12934

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
print("The movie titled \"Batman\" has been released in the year:")
mov = titles[titles.title == 'Batman'].reset_index(drop=True)
print(mov[['year']])
# Out:
# The movie titled "Batman" has been released in the year:
#    year
# 0  1943
# 1  1989

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
print("Number of Roles that were there in the movie \"Inception\" is:")
print(len(cast[cast['title']=='Inception'].type),"i.e")
lst = list (cast[cast.title == "Inception"].type.unique())
print(lst)
# Out:
# Number of Roles that were there in the movie "Inception" is:
# 78 i.e
# ['actor', 'actress']

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
print("Number of roles in the movie \"Inception\" that are NOT ranked by an \"n\" value is:")
print(cast[cast.title == "Inception"].n.isna().sum())
print("The roles are displayed below:")
cast[(cast['title']=='Inception')&(cast['n'].isnull()==True)]
# Out:
# Number of roles in the movie "Inception" that are NOT ranked by an "n" value is:
# 27
# The roles are displayed below:
#              title  year                     name     type  \
# 98153    Inception  2010     Michael (III) August    actor
# 197877   Inception  2010                 Ken Bhan    actor
# 374661   Inception  2010            John Ceallach    actor
# 497161   Inception  2010             Garvin Cross    actor
# 684098   Inception  2010            Seve Esposito    actor
# 690634   Inception  2010      Marcus (II) Everett    actor
# 707642   Inception  2010  Zachary Christopher Fay    actor
# 836295   Inception  2010        Daniel Girondeaud    actor
# 1006636  Inception  2010          Andrew Hoagland    actor
# 1095095  Inception  2010          Charles Jarrell    actor
# 1108755  Inception  2010            Seong-hwan Jo    actor
# 1120184  Inception  2010          Alonzo F. Jones    actor
# 1189066  Inception  2010               Mobin Khan    actor
# ...

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
print("Number of roles in the movie \"Inception\" that received an \"n\" value is:")
print(cast[cast.title == "Inception"].n.notna().sum())
print("The roles are displayed below:")
cast[(cast['title']=='Inception')&(cast['n'].notnull()==True)]
# Out:
# Number of roles in the movie "Inception" that received an "n" value is:
# 51
# The roles are displayed below:
#              title  year                  name     type  \
# 149008   Inception  2010          Peter Basham    actor
# 183937   Inception  2010          Tom Berenger    actor
# 260128   Inception  2010        Virgile Bramly    actor
# 326745   Inception  2010         Michael Caine    actor
# 333415   Inception  2010          Earl Cameron    actor
# 433867   Inception  2010         Nicolas Clerc    actor
# 444385   Inception  2010        Adam (IV) Cole    actor
# 517227   Inception  2010    Jean-Michel Dagory    actor
# 590576   Inception  2010     Leonardo DiCaprio    actor
# 709436   Inception  2010             Russ Fega    actor
# 737322   Inception  2010      Mark Fleischmann    actor
# 807795   Inception  2010        Michael Gaston    actor
# 812135   Inception  2010       Johnathan Geare    actor
# 832083   Inception  2010         Carl Gilliard    actor
# ...

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
print("The cast of \"North by Northwest\" in their correct \"n\"-value order, ignoring roles that did not earn a numeric \"n\" value are:  ")
lst = cast[cast.title == "North by Northwest"].sort_values('n').dropna().reset_index(drop=True)
print(lst[['type','n']])
# Out:
# The cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value are:
#        type     n
# 0     actor   1.0
# 1   actress   2.0
# 2     actor   3.0
# 3   actress   4.0
# 4     actor   5.0
# 5   actress   6.0
# 6     actor   7.0
# 7     actor   8.0
# 8     actor   9.0
# 9     actor  10.0
# 10    actor  11.0
# 11    actor  12.0
# 12    actor  13.0
# 13    actor  14.0
# 14    actor  15.0
# 15    actor  16.0

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
print("The entire cast, in \"n\"-order, of the 1972 film \"Sleuth\" are: ")
# Element-wise logical AND(we use "&" symbol) and for logical AND (we use "and") 
lst = cast[(cast.title == "Sleuth") & (cast.year == 1972)].sort_values('n').reset_index(drop=True) 
print(lst[['type','n','title','year']])
# Out:
# The entire cast, in "n"-order, of the 1972 film "Sleuth" are:
#       type    n   title  year
# 0    actor  1.0  Sleuth  1972
# 1    actor  2.0  Sleuth  1972
# 2    actor  3.0  Sleuth  1972
# 3    actor  4.0  Sleuth  1972
# 4  actress  5.0  Sleuth  1972
# 5    actor  6.0  Sleuth  1972

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
print("The entire cast, in \"n\"-order, of the 2007 version of \"Sleuth\" are: ")
lst = cast[(cast.title == "Sleuth") & (cast.year == 2007)].sort_values('n').reset_index(drop=True) 
print(lst[['type','n','title','year']])
# Out:
# The entire cast, in "n"-order, of the 2007 version of "Sleuth" are:
#       type    n   title  year
# 0    actor  1.0  Sleuth  2007
# 1    actor  2.0  Sleuth  2007
# 2    actor  3.0  Sleuth  2007
# 3    actor  NaN  Sleuth  2007
# 4    actor  NaN  Sleuth  2007
# 5  actress  NaN  Sleuth  2007
# 6  actress  NaN  Sleuth  2007

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
print(
    "The number of roles that were credited in the silent 1921 version of Hamlet are"
)
print(len(cast[(cast.title == "Hamlet") & (cast.year == 1921)]))
print("The roles are displayed below:")
cast[(cast.title == "Hamlet") & (cast.year == 1921)]
# Out:
# The number of roles that were credited in the silent 1921 version of Hamlet are
# 9
# The roles are displayed below:
#           title  year                    name     type         character    n
# 7789     Hamlet  1921        Fritz Achterberg    actor       Fortinbras,  9.0
# 458904   Hamlet  1921            Paul Conradi    actor      K?nig Hamlet  2.0
# 555034   Hamlet  1921        Anton De Verdier    actor           Laertes  7.0
# 1135279  Hamlet  1921         Hans Junkermann    actor          Polonius  6.0
# 2185558  Hamlet  1921            Heinz Stieda    actor           Horatio  5.0
# 2375993  Hamlet  1921  Eduard von Winterstein    actor          Claudius  4.0
# 2664423  Hamlet  1921         Mathilde Brandt  actress  K?nigin Gertrude  3.0
# 3062023  Hamlet  1921          Lilly Jacobson  actress           Ophelia  8.0
# 3355176  Hamlet  1921            Asta Nielsen  actress            Hamlet  1.0

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
print(
    "The number of roles that were credited in the Branagh's 1996 Hamlet is:")
print(len(cast[(cast.title == 'Hamlet') & (cast.year == 1996)]))
print("The roles are displayed below:")
cast[(cast.title == 'Hamlet') & (cast.year == 1996)]
# Out:
# The number of roles that were credited in the Branagh's 1996 Hamlet is:
# 54
# The roles are displayed below:
#           title  year                    name     type  \
# 1731     Hamlet  1996              Riz Abbasi    actor
# 95861    Hamlet  1996    Richard Attenborough    actor
# 158642   Hamlet  1996     Simon Russell Beale    actor
# 214473   Hamlet  1996         David (V) Blair    actor
# 219554   Hamlet  1996           Brian Blessed    actor
# 250773   Hamlet  1996      Christopher Bowles    actor
# 260225   Hamlet  1996         Kenneth Branagh    actor
# 272749   Hamlet  1996          Richard Briers    actor
# 294652   Hamlet  1996          Michael Bryant    actor
# 319501   Hamlet  1996            Peter Bygott    actor
# 344365   Hamlet  1996       Kenneth W Caravan    actor
# 500916   Hamlet  1996           Billy Crystal    actor
# 518572   Hamlet  1996           Charles Daish    actor
# 576147   Hamlet  1996        G?rard Depardieu    actor
# ...

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
print(
    "The number of roles of \"Hamlet\" that have been listed in all film credits through history is:"
)
print(len(cast[(cast.title == 'Hamlet') & (cast.character == "Hamlet")]))
print("The roles are displayed below:")
cast[(cast.title == 'Hamlet') & (cast.character == "Hamlet")]
# Out:
# The number of roles of "Hamlet" that have been listed in all film credits through history is:
# 18
# The roles are displayed below:
#           title  year                       name     type character    n
# 260225   Hamlet  1996            Kenneth Branagh    actor    Hamlet  5.0
# 312781   Hamlet  1964             Richard Burton    actor    Hamlet  1.0
# 432307   Hamlet  2017                  Tom Clear    actor    Hamlet  NaN
# 746646   Hamlet  1913  Johnston Forbes-Robertson    actor    Hamlet  2.0
# 826565   Hamlet  1990                 Mel Gibson    actor    Hamlet  1.0
# 842847   Hamlet  2016              Jonathan Goad    actor    Hamlet  NaN
# 961566   Hamlet  2000                Ethan Hawke    actor    Hamlet  1.0
# 1498929  Hamlet  1973               Rick McKenna    actor    Hamlet  NaN
# 1518580  Hamlet  2009             David Melville    actor    Hamlet  1.0
# 1530280  Hamlet  1976                David Meyer    actor    Hamlet  6.0
# ...

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
print("The number of people who have played \"Ophelia\" is:")
print(len(cast[cast.character == "Ophelia"]))
print("The names are listed below:")
cast[cast.character == "Ophelia"]
# Out:
# The number of people who have played "Ophelia" is:
# 117
# The names are listed below:
#                                                      title  year  \
# 248251                          The Merry Maids of Madness  2016
# 410247                                      Jake Gets Paid  2009
# 470859                                          Inoperable  2017
# 866334                     Dogg's Hamlet, Cahoot's Macbeth  2005
# 1364457                                                 11  2014
# ...                                                    ...   ...
# 3722298                                           D.C. Cab  1983
# 3723039                                           Creature  2011
# 3733637                                             Hamlet  2015
# 3748118  National Theatre Live: Rosencrantz & Guildenst...  2017
# 3751232                                             Hamlet  1996
#
#                          name     type character     n
# ...

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
print("The number of people who have played  ta role called \"The Dude\" is:")
print(len(cast[cast.character == "The Dude"]))
print("The names are listed below:")
cast[cast.character == "The Dude"]
# Out:
# The number of people who have played  ta role called "The Dude" is:
# 19
# The names are listed below:
#                                   title  year                  name   type  \
# 272161                 The Big Lebowski  1998          Jeff Bridges  actor
# 339389               Terms & Conditions  2015           Jordan Cann  actor
# 498660                         Stranger  2000         Scott Crowell  actor
# 570128           Pizza Man vs. the Dude  2004        Chris DeMarcus  actor
# 610791                      Sweepstakes  1931           Mike Donlin  actor
# 629473                    Self Helpless  2010        Devin The Dude  actor
# 855976                A Few Brains More  2012    Michael D. Goodwin  actor
# 1089444  Jay and Silent Bob Strike Back  2001   Matthew (XIX) James  actor
# 1138933                   Explicit Ills  2008    Christopher Kadish  actor
# 1367230                 American Idiots  2013      Jason Loughridge  actor
# ...

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
print("The number of people who have played  ta role called \"The Stranger\" is:")
print(len(cast[cast.character == "The Stranger"]))
print("The names are listed below:")
cast[cast.character == "The Stranger"]
# Out:
# The number of people who have played  ta role called "The Stranger" is:
# 212
# The names are listed below:
#                             title  year                       name     type  \
# 25954                       Theeb  2014  Hassan Mutlag Al-Maraiyeh    actor
# 35748              My Time to Die  2014       Vincent H. Alexander    actor
# 46418                      Hickok  2017               Terral Altom    actor
# 67421                    Get Mean  1975               Tony Anthony    actor
# 67424    Lo straniero di silenzio  1968               Tony Anthony    actor
# ...                           ...   ...                        ...      ...
# 3219011            Ever Since Eve  1921                Ethel Lynne  actress
# 3405700              Weitertanzen  2008             Rosa Maria Paz  actress
# 3427715               The Godsend  1980           Angela Pleasence  actress
# 3567516                Motherland  1927            Dorinea Shirley  actress
# ...

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
print("The number of roles that Sidney Poitier has played throughout his career is:")
print(len(cast[cast.name == "Sidney Poitier"]))
print("The roles are displayed below:")
cast[cast.name == "Sidney Poitier"]
# Out:
# The number of roles that Sidney Poitier has played throughout his career is:
# 43
# The roles are displayed below:
#                                 title  year            name   type  \
# 1816209               A Patch of Blue  1965  Sidney Poitier  actor
# 1816210         A Piece of the Action  1977  Sidney Poitier  actor
# 1816211           A Raisin in the Sun  1961  Sidney Poitier  actor
# 1816212               A Warm December  1973  Sidney Poitier  actor
# 1816213             All the Young Men  1960  Sidney Poitier  actor
# 1816214                Band of Angels  1957  Sidney Poitier  actor
# 1816215             Blackboard Jungle  1955  Sidney Poitier  actor
# 1816216                  Brother John  1971  Sidney Poitier  actor
# 1816217         Buck and the Preacher  1972  Sidney Poitier  actor
# 1816218      Cry, the Beloved Country  1951  Sidney Poitier  actor
# 1816219                Duel at Diablo  1966  Sidney Poitier  actor
# ...

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
print("The number of roles that Judi Dench has played is:")
print(len(cast[cast.name == "Judi Dench"]))
print("The roles are displayed below:")
cast[cast.name == "Judi Dench"]
# Out:
# The number of roles that Judi Dench has played is:
# 55
# The roles are displayed below:
#                                                title  year        name  \
# 2814206                        84 Charing Cross Road  1987  Judi Dench
# 2814207                            A Handful of Dust  1988  Judi Dench
# 2814208                    A Midsummer Night's Dream  1968  Judi Dench
# 2814209                           A Room with a View  1985  Judi Dench
# 2814210                            A Study in Terror  1965  Judi Dench
# 2814211       Angelina Ballerina: Angelina Sets Sail  2006  Judi Dench
# 2814212      Branagh Theatre Live: The Winter's Tale  2015  Judi Dench
# 2814213                                Casino Royale  2006  Judi Dench
# 2814214                                     Chocolat  2000  Judi Dench
# 2814215                                    Dead Cert  1974  Judi Dench
# 2814216                              Die Another Day  2002  Judi Dench
# ...

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
print(
    "The list of supporting roles played by Cary Grant in 1940's ordered by year are:"
)
cast[(cast.name == "Cary Grant") & (cast.n == 2) & (cast.year >= 1940) &
     (cast.year <= 1949)].sort_values(by=['year'])
# Out:
# The list of supporting roles played by Cary Grant in 1940's ordered by year are:
#                    title  year        name   type    character    n
# 871423  My Favorite Wife  1940  Cary Grant  actor   Nick Arden  2.0
# 871433    Penny Serenade  1941  Cary Grant  actor  Roger Adams  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
print(
    "The list of leading roles played by Cary Grant in 1940's ordered by year are:"
)
cast[(cast.name == "Cary Grant") & (cast.year >= 1940) & (cast.year <= 1949)].sort_values(by=['year'])
# Out:
# The list of leading roles played by Cary Grant in 1940's ordered by year are:
#                                        title  year        name   type  \
# 871450                The Philadelphia Story  1940  Cary Grant  actor
# 871448               The Howards of Virginia  1940  Cary Grant  actor
# 871407                       His Girl Friday  1940  Cary Grant  actor
# 871423                      My Favorite Wife  1940  Cary Grant  actor
# 871438                             Suspicion  1941  Cary Grant  actor
# 871433                        Penny Serenade  1941  Cary Grant  actor
# 871452                  The Talk of the Town  1942  Cary Grant  actor
# 871429                 Once Upon a Honeymoon  1942  Cary Grant  actor
# 871398                     Destination Tokyo  1943  Cary Grant  actor
# 871422                             Mr. Lucky  1943  Cary Grant  actor
# 871390                  Arsenic and Old Lace  1944  Cary Grant  actor
# ...

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
print("The Number of roles that were available for actors in the 1950s is:")
print(len(cast[(cast.type == "actor") & (cast.year >= 1950) & (cast.year <= 1959)].sort_values(by=['year'])))
# Out:
# The Number of roles that were available for actors in the 1950s is:
# 157738

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
print("The Number of roles that were available for actresses in the 1950s is:")
print(len(cast[(cast.type == "actress") & (cast.year >= 1950) & (cast.year <= 1959)].sort_values(by=['year'])))
# Out:
# The Number of roles that were available for actresses in the 1950s is:
# 57733

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
print("The number of leading roles\(n=1\) that were available from the beginning of film history through 1980 are:")
print(len(cast[(cast.year <= 1980) & (cast.n == 1)].type))
# Out:
# The number of leading roles\(n=1\) that were available from the beginning of film history through 1980 are:
# 65140

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %%
print("The number of non-leading roles\(n=1\) that were available from the beginning of film history through 1980 are:")
print(len(cast[(cast.year <= 1980) & (cast.n != 1)].type))
# Out:
# The number of non-leading roles\(n=1\) that were available from the beginning of film history through 1980 are:
# 1117667

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
print("The number of non-leading roles\(n=1\) that were available from the beginning of film history through 1980 are:")
print(len(cast[(cast.year == 1980) & (cast.n.isnull() == True)]))
# Out:
# The number of non-leading roles\(n=1\) that were available from the beginning of film history through 1980 are:
# 4466

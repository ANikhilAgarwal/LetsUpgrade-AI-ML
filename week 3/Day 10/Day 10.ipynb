# %% [markdown]
# # Question :
# As we have learned to find out statistical test like mean median standard deviation using
# python so practice those methods and using the results write down 10 hypothesis and submit.
#
#
# Dataset: Same as given on day 7 of Company XYZ of attrition

# %%
# Importing Libraries that is required for our project and initializing it for easy usage in future.
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing our dataset
dataset = pd.read_csv("general_data.csv")

# %%
# Reviewing the first 5 rows in the dataset
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
# reviewing the columns labels of the dataset.
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.shape # reviewing the shape of dataset before removing null valued column.
# Out:
# (4410, 24)

# %%
dataset.isnull().sum() # display number of null values for each attribute.
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
dataset.dropna(inplace = True) # Droping the null values permanently.

# %%
dataset.shape # reviewing the shape of dataset after removing null valued column.
# Out:
# (4382, 24)

# %%
dataset.describe() # printing the statistical summary of the dataset for numeric columns only.
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4382.000000       4382.000000  4382.000000         4382.0  4382.000000
# mean     36.933364          9.198996     2.912369            1.0  2207.804884
# std       9.137272          8.105396     1.024728            0.0  1271.688783
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1108.250000
# 50%      36.000000          7.000000     3.000000            1.0  2208.500000
# 75%      43.000000         14.000000     4.000000            1.0  3308.750000
# max      60.000000         29.000000     5.000000            1.0  4409.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4382.000000    4382.000000         4382.000000        4382.000000
# mean      2.063898   65061.702419            2.693291          15.210634
# ...

# %%
dataset.median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                  2208.5
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
dataset.mode(dropna=False)
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0     35.0        No  Travel_Rarely  Research & Development               2.0
# 1      NaN       NaN            NaN                     NaN               NaN
# 2      NaN       NaN            NaN                     NaN               NaN
# 3      NaN       NaN            NaN                     NaN               NaN
# 4      NaN       NaN            NaN                     NaN               NaN
# ...    ...       ...            ...                     ...               ...
# 4377   NaN       NaN            NaN                     NaN               NaN
# 4378   NaN       NaN            NaN                     NaN               NaN
# 4379   NaN       NaN            NaN                     NaN               NaN
# 4380   NaN       NaN            NaN                     NaN               NaN
# 4381   NaN       NaN            NaN                     NaN               NaN
#
# ...

# %%
dataset.var()
# Out:
# Age                        8.348974e+01
# DistanceFromHome           6.569744e+01
# Education                  1.050068e+00
# EmployeeCount              0.000000e+00
# EmployeeID                 1.617192e+06
# JobLevel                   1.223490e+00
# MonthlyIncome              2.222397e+09
# NumCompaniesWorked         6.239165e+00
# PercentSalaryHike          1.341762e+01
# StandardHours              0.000000e+00
# StockOptionLevel           7.265814e-01
# TotalWorkingYears          6.061739e+01
# TrainingTimesLastYear      1.662558e+00
# YearsAtCompany             3.756894e+01
# YearsSinceLastPromotion    1.040059e+01
# YearsWithCurrManager       1.274257e+01
# dtype: float64

# %%
np.std(dataset)
# Out:
# Age                            9.136229
# DistanceFromHome               8.104471
# Education                      1.024612
# EmployeeCount                  0.000000
# EmployeeID                  1271.543671
# JobLevel                       1.105988
# MonthlyIncome              47136.930782
# NumCompaniesWorked             2.497547
# PercentSalaryHike              3.662589
# StandardHours                  0.000000
# StockOptionLevel               0.852300
# TotalWorkingYears              7.784828
# TrainingTimesLastYear          1.289255
# YearsAtCompany                 6.128651
# YearsSinceLastPromotion        3.224626
# YearsWithCurrManager           3.569267
# dtype: float64

# %% [markdown]
# # Hypothesis

# %% [markdown]
# ### H1: If Percent Salary Hike is more then attrition could decrease.
# ### H2: If Years Since Last Promotion is lowere then attrition could decrease.
# ### H3: If employeers worked for more number of years with current manager then attrition could be decreased.
# ### H4: There is a significant relation between YearsAtCompany and Attrition
# ### H5: There is a significant relation between JobLevel and employee retention
# ### H6: There is a significant relation between YearsAtCompany and Attrition
# ### H7: There is a signifcant relation between Education and Attrition
# ### H8: There is a significant relation between TrainingTimesLastYear and Attrition
# ### H9: There is a significant relation between JobLevel and Attrition.
# ### H10: If Distance From Home of employeers is less then attrition could decrease.
